# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-macosx_10_9_x86_64.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: matplotlib in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: numpy>=1.6.1 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 1.5 MB/s eta 0:00:0000:0100:01
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.1-cp39-cp39-macosx_10_9_x86_64.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.8/381.8 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.6 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from konlpy) (1.21.5)
# Requirement already satisfied: lxml>=4.1.0 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from konlpy) (4.9.1)
# Requirement already satisfied: packaging in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/min0/Downloads/anaconda3/lib/python3.9/site-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.9)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.1 konlpy-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
with open('/Users/min0/Documents/Documents/school/4-1/빅데이터/jupyter/bd0412 - 크롤링/살인_naver_news.json', 'r', encoding='utf-8') as f:
    json_data = json.load(f)

file = open("textfile.txt", "w", encoding='utf-8');
for i in range(len(json_data)):
    file.write(json_data[i]['title'])
    
    
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
# 한글 폰트 패스로 지정
import re
import nltk

# %%
JVM_PATH = '/Library/Java/JavaVirtualMachines/jdk1.8.0_361.jdk/Contents/Home/jre/lib/jli/libjli.dylib'
#'/Library/Java/JavaVirtualMachines/zulu-15.jdk/Contents/Home/bin/java'

# %%
from konlpy.tag import Okt;
t = Okt(jvmpath=JVM_PATH)

# %%
# 문장에서 필요 없는 데이터
stop_words = [')','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','라고','중요한','합','가요','....','보이','네','무지','했습니다',
              '이다','대해','에게','입니다','있다','사람','대한','3','합니다','및','장','에서','하고','검','한다','만',
             '적', '성', '삼', '등', '전', '인', '그', '했다', '와', '위', '해', '권', '된', '서', '말', '분',
             '영화', '감독', '다큐멘터리', '다큐','것', '그', '이', '수', '사람', '인간', '최고', '우리', '생각', '자신', '이야기', '점', '현실', '더', '보고', '존재', '모습', 
                       '속', '말', '장면', '일', '대한', '뿐',  '가장', '때', '정말', '지금', '나', '상황', '정도' '면', '습', '게', '자', '끝', '볼', '건', '못', 
                       '마치', '과로', '기도', '보', '곳', '그', '이상', '원래', '일이', '전', '사람', '도', '막', '를', '다른', '부터', '자기', '시대','평',
                       '소리', '뭐', '더', '막상', '전혀', '내', '살', '현재', '지금', '이제',  '사', '인', '법', '노인', '꼭', '간','향후', '사회', '당신', '손', 
                       '저', '경우', '전', '얼마', '일단', '걸', '안', '바로', '그냥', '위해', '때문', '은', '앞',  '볼', '자기', '처럼', '순간', '앞', '감정', 
                       '관련', '일', '가야', '살', '보','요', '보고', '수', '제', '두', '몇', '제', '죽', '때', '해', '이', '중', '내내', '후', '정도', '변화', '감',
                       '여러','대한', '것', '시작', '래야', '진짜','또', '수도', '오히려', '니', '여기', '꼭', '과연', '나라', '자', '과거', '최후', '무엇',
                       '누가', '뒤', '얘기', '방식', '알', '그것', '탓', '계속', '방법', '대해', '마지막', '악', '처음', '기분', '의미', '놈', '승리',
                       '역사'
             ]

# %%
spwords = set(STOPWORDS) 

content_text = open("textfile.txt", 'r', encoding='utf-8').read()

# %%
def strip_e(st):
    RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    return RE_EMOJI.sub(r'', st)

# %%
content_text=strip_e(content_text)
tokens_ko = t.morphs(content_text)
tokens_ko = t.nouns(content_text) # 명사만 빼내기
tokens_ko

ko = nltk.Text(tokens_ko)   
print(len(ko.tokens))          # 토큰 전체 갯수
print(len(set(ko.tokens)))     # 토큰 unique 갯수
ko = nltk.Text(tokens_ko)
ko.vocab().most_common(100) 

tokens_ko = [each_word for each_word in tokens_ko
             if each_word not in stop_words]

ko = nltk.Text(tokens_ko)
ko.vocab().most_common(50)
plt.rcParams['font.family'] = 'AppleGothic'
plt.figure(figsize=(15,6))
ko.plot(30) 
plt.show()
# Out:
# 8252
# 2049

# %%
# 나는 맥이어서 안 해도 ㄱㅊ
# 그래프에서 한글 폰트 깨지는 문제에 대한 대처(전역 글꼴 설정)
#from matplotlib import font_manager, rc
#font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
#rc('font', family=font_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/b9/x_2_sqpd5y3393q9vwpcscjm0000gn/T/ipykernel_530/1976295134.py in <module>
#       1 # 그래프에서 한글 폰트 깨지는 문제에 대한 대처(전역 글꼴 설정)
#       2 from matplotlib import font_manager, rc
# ----> 3 font_name = font_manager.FontProperties(fname='c:/Windows/Fonts/malgun.ttf').get_name()
#       4 rc('font', family=font_name)
#
# ~/Downloads/anaconda3/lib/python3.9/site-packages/matplotlib/font_manager.py in get_name(self)
#     735         Return the name of the font that best matches the font properties.
#     736         """
# --> 737         return get_font(findfont(self)).family_name
#     738
#     739     def get_style(self):
#
# ~/Downloads/anaconda3/lib/python3.9/site-packages/matplotlib/font_manager.py in get_font(filename, hinting_factor)
#    1422         hinting_factor = rcParams['text.hinting_factor']
#    1423     # also key on the thread ID to prevent segfaults with multi-threading
# -> 1424     return _get_font(filename, hinting_factor,
#    1425                      _kerning_factor=rcParams['text.kerning_factor'],
#    1426                      thread_id=threading.get_ident())
#
# ~/Downloads/anaconda3/lib/python3.9/site-packages/matplotlib/font_manager.py in _get_font(filename, hinting_factor, _kerning_factor, thread_id)
#    1403 @lru_cache(64)
#    1404 def _get_font(filename, hinting_factor, *, _kerning_factor, thread_id):
# -> 1405     return ft2font.FT2Font(
#    1406         filename, hinting_factor, _kerning_factor=_kerning_factor)
#    1407
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/min0/Documents/Documents/school/4-1/빅데이터/jupyter/bd0412 - 크롤링/c:/Windows/Fonts/malgun.ttf'

# %%
data = ko.vocab().most_common(300)
print(len(data))
data
# Out:
# 300
# [('살인', 187),
#  ('살해', 176),
#  ('납치', 175),
#  ('강남', 167),
#  ('배후', 127),
#  ('구속', 92),
#  ('재력', 80),
#  ('코인', 78),
#  ('아내', 76),
#  ('부부', 70),
#  ('사건', 64),
#  ('음주운전', 50),
#  ('공개', 50),
#  ('부인', 50),
#  ('심사', 46),
#  ('청춘', 44),
#  ('월담', 44),
#  ('선수', 42),
#  ('상장', 42),
#  ('씨름', 41),
#  ('이웃', 40),
#  ('명', 39),
#  ('길복순', 39),
#  ('박형식', 36),
#  ('의혹', 34),
#  ('층간소음', 32),
#  ('처벌', 31),
#  ('신상', 31),
#  ('징역', 31),
#  ('영장', 30),
#  ('승아', 29),
#  ('사고', 27),
#  ('오늘', 27),
#  ('전직', 27),
#  ('검찰', 26),
#  ('뉴스', 25),
#  ('범죄', 25),
#  ('황', 25),
#  ('경찰', 24),
#  ('윷놀이', 24),
#  ('방화', 23),
#  ('청부', 23),
#  ('남성', 22),
#  ('돌려차기', 22),
#  ('유족', 22),
#  ('결정', 21),
#  ('사망', 21),
#  ('갈등', 21),
#  ('여부', 20),
#  ('복수', 20),
#  ('부산', 20),
#  ('여왕', 20),
#  ('모씨', 20),
#  ('내일', 19),
#  ('가면', 19),
#  ('음주', 18),
#  ('스쿨존', 18),
#  ('전도연', 18),
#  ('미끼', 18),
#  ('종합', 18),
#  ('운전자', 17),
#  ('보복', 17),
#  ('피의자', 17),
#  ('이경우', 17),
#  ('시세', 16),
#  ('뒷돈', 16),
#  ('명의', 16),
#  ('가입', 16),
#  ('전쟁', 16),
#  ('모두', 16),
#  ('실형', 16),
#  ('한강', 16),
#  ('남편', 15),
#  ('시신', 15),
#  ('대전', 15),
#  ('마약', 15),
#  ('정황', 15),
#  ('장근석', 15),
#  ('생명보험', 15),
#  ('간호', 15),
#  ('호란', 15),
#  ('동료', 15),
#  ('조금', 15),
#  ('조종', 14),
#  ('집', 14),
#  ('인터뷰', 14),
#  ('배우', 14),
#  ('돈', 14),
#  ('직원', 14),
#  ('혐의', 14),
#  ('피해자', 14),
#  ('배', 14),
#  ('글로리', 14),
#  ('출석', 14),
#  ('대법', 14),
#  ('공제', 14),
#  ('여자친구', 13),
#  ('모텔', 13),
#  ('전소', 13),
#  ('그대', 13),
#  ('얼굴', 13),
#  ('범', 13),
#  ('울산', 13),
#  ('복면', 13),
#  ('몸통', 13),
#  ('선택', 12),
#  ('발인', 12),
#  ('충격', 12),
#  ('송치', 12),
#  ('수사', 12),
#  ('시민', 12),
#  ('김선아', 12),
#  ('김지민', 12),
#  ('오아시스', 12),
#  ('동윤', 12),
#  ('호', 12),
#  ('왕', 12),
#  ('로맨스', 11),
#  ('발견', 11),
#  ('죄', 11),
#  ('시간', 11),
#  ('차', 11),
#  ('항소', 11),
#  ('브로커', 11),
#  ('처리', 11),
#  ('서지혜', 11),
#  ('이원정', 11),
#  ('선', 11),
#  ('범행', 11),
#  ('폭행', 11),
#  ('사망자', 11),
#  ('정웅인', 11),
#  ('거래소', 11),
#  ('만취', 11),
#  ('의심', 11),
#  ('회', 11),
#  ('오토바이', 11),
#  ('구속영장', 11),
#  ('묵묵', 11),
#  ('구타', 11),
#  ('콘텐츠', 11),
#  ('랭킹', 11),
#  ('박수홍', 11),
#  ('극단', 10),
#  ('킬링', 10),
#  ('시도', 10),
#  ('참변', 10),
#  ('운동', 10),
#  ('총격', 10),
#  ('흉기', 10),
#  ('보험', 10),
#  ('중재', 10),
#  ('예고', 10),
#  ('자산', 10),
#  ('장미', 10),
#  ('이봉', 10),
#  ('련', 10),
#  ('호소', 10),
#  ('지목', 10),
#  ('브레이크', 10),
#  ('태국', 10),
#  ('우려', 10),
#  ('대죄', 10),
#  ('이유', 10),
#  ('판도라', 10),
#  ('장희진', 10),
#  ('채', 9),
#  ('구의회', 9),
#  ('규탄', 9),
#  ('연기', 9),
#  ('사랑', 9),
#  ('계획', 9),
#  ('차례', 9),
#  ('단독', 9),
#  ('문학소녀', 9),
#  ('소년', 9),
#  ('대가', 9),
#  ('불', 9),
#  ('성폭행', 9),
#  ('억대', 9),
#  ('의료법', 9),
#  ('번', 9),
#  ('가해자', 9),
#  ('가상', 9),
#  ('이규', 9),
#  ('동상', 9),
#  ('가족', 9),
#  ('교사', 9),
#  ('출연', 9),
#  ('장대', 9),
#  ('김다예', 9),
#  ('잔혹', 8),
#  ('의식', 8),
#  ('적용', 8),
#  ('오열', 8),
#  ('엄중', 8),
#  ('여친', 8),
#  ('종영', 8),
#  ('강력', 8),
#  ('위기', 8),
#  ('서명', 8),
#  ('음악', 8),
#  ('로부터', 8),
#  ('안전', 8),
#  ('투자', 8),
#  ('철', 8),
#  ('싹둑', 8),
#  ('장인', 8),
#  ('장모', 8),
#  ('오지호', 8),
#  ('통합', 8),
#  ('눈', 7),
#  ('티저', 7),
#  ('대책', 7),
#  ('영상', 7),
#  ('다시', 7),
#  ('항소심', 7),
#  ('화폐', 7),
#  ('가정폭력', 7),
#  ('카지노', 7),
#  ('금지', 7),
#  ('리포트', 7),
#  ('팀', 7),
#  ('동기', 7),
#  ('이슈', 7),
#  ('몽', 7),
#  ('언급', 7),
#  ('피', 7),
#  ('진심', 7),
#  ('피해', 7),
#  ('운전', 7),
#  ('범죄자', 7),
#  ('유선', 7),
#  ('왜', 7),
#  ('동안', 7),
#  ('이몽', 7),
#  ('반전', 7),
#  ('증거', 7),
#  ('멸', 7),
#  ('협박', 7),
#  ('경찰관', 7),
#  ('재심', 7),
#  ('칼부림', 7),
#  ('이연', 7),
#  ('배상금', 7),
#  ('지옥', 7),
#  ('강화', 6),
#  ('목소리', 6),
#  ('캐릭터', 6),
#  ('보호', 6),
#  ('유기한', 6),
#  ('톡톡', 6),
#  ('복귀', 6),
#  ('작품', 6),
#  ('현장', 6),
#  ('술', 6),
#  ('문제', 6),
#  ('여성', 6),
#  ('임', 6),
#  ('이번', 6),
#  ('발단', 6),
#  ('포착', 6),
#  ('쇼', 6),
#  ('배달', 6),
#  ('보험금', 6),
#  ('죽음', 6),
#  ('제대로', 6),
#  ('폭발', 6),
#  ('접근', 6),
#  ('민주당', 6),
#  ('어린이', 6),
#  ('구역', 6),
#  ('배신', 6),
#  ('정부', 6),
#  ('공무원', 6),
#  ('개월', 6),
#  ('건설', 6),
#  ('연상', 6),
#  ('착수금', 6),
#  ('딸', 6),
#  ('결론', 6),
#  ('반격', 6),
#  ('아들', 6),
#  ('연속', 6),
#  ('결혼', 6),
#  ('토막', 6),
#  ('참극', 6),
#  ('술자리', 6),
#  ('향', 6),
#  ('선고', 6),
#  ('논란', 6),
#  ('감옥', 6),
#  ('인조', 6),
#  ('실패', 6),
#  ('제안', 6),
#  ('경기', 5),
#  ('강력범죄', 5),
#  ('시청자', 5),
#  ('말다툼', 5),
#  ('정진운', 5)]

# %%
# list tuple을 딕셔너리로 만들어주는 함수 - Uchang
def todict(list_tuple):    
    todict = {}
    for i in range(0,len(list_tuple)):
        todict[data[i][0]] = data[i][1]
    return todict

# %%
# 워드클라우드를 그려보자
wordcloud = WordCloud(font_path='/System/Library/Fonts/Supplemental/AppleGothic.ttf',
                      relative_scaling = 0.2,
                      #stopwords=STOPWORDS,
                      background_color='white',
                      ).generate_from_frequencies(todict(data))

plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
