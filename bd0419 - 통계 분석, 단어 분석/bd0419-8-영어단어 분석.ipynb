# %%
import pandas as pd
import glob
import re
from functools import reduce

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from collections import Counter

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
# 8장. 텍스트빈도분석 - 1.영어단어분석

# 영어 단어 분석에 필요한 패키지 준비
#get_ipython().system('pip install matplotlib  #최초 한번만 설치:Anaconda에 설치됨')
#get_ipython().system('pip install wordcloud  #최초 한번만 설치:Anaconda에 설치됨')

# %%
# # 1. 데이터 준비
# ### 1-1. 파일 병합
# ### - ☺데이터를 다운 받은 시점에 따라 검색결과가 달라지므로, 책에 있는 결과 화면과 다를수 있습니다.☺ -
# In[2]:
all_files = glob.glob('/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData*.xls')
all_files #출력하여 내용 확인
# Out:
# ['/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (4).xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (8).xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (9).xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (5).xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (2).xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (3).xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (1).xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (6).xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData.xls',
#  '/Users/min0/Documents/Documents/school/4-1/빅데이터/자료/week07/8장_data/myCabinetExcelData (7).xls']

# %%
all_files_data = [] #저장할 리스트 

for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)

all_files_data[0] #출력하여 내용 확인
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1                  Big data promises big opportunity
# 1          NaN    2  Big data vs accurate data in health research: ...
# 2          NaN    3  Data stream classification and big data analytics
# 3          NaN    4  Big Data and Privacy: Why Public Organizations...
# 4          NaN    5  Big data on individuals in the architectural d...
# ..         ...  ...                                                ...
# 95         NaN   96  Big data analytics sentiment: US-China reactio...
# 96         NaN   97  Big Data In the first of three articles on Big...
# 97         NaN   98  Big data driven lithium-ion battery modeling m...
# 98         NaN   99  Big data in multiple sclerosis: development of...
# 99         NaN  100  Data Fusion of Small Sample Flying Test Data a...
#
#                                                    저자  \
# 0                                           Davis, B.
# 1   Brodie, M.A.; Pliner, E.M.; Ho, A.; Li, Kalina...
# 2          Krawczyk, B.; Stefanowski, J.; Wozniak, M.
# 3                                 Prince, Christopher
# 4               Meekings, Scott; Schnabel, Marc Aurel
# ..                                                ...
# 95  LaBrie, Ryan C.; Steinke, Gerhard H.; Li, Xian...
# 96                                            unknown
# 97             Li, Shuangqi; He, Hongwen; Li, Jianwei
# 98                                            unknown
# 99  Ning,  Xiaolei; Wu,  Yingxia; Zhang,  Hailin; ...
#
#                                   출판사   출판일
# 0              INSTITUTE OF PETROLEUM  2014
# 1    Elsevier Science B.V., Amsterdam  2018
# 2   Elsevier Science B.V., Amsterdam.  2015
# 3   University of Toronto Press; 1998  2017
# 4                    Taylor & Francis  2017
# ..                                ...   ...
# 95  Elsevier Science B.V., Amsterdam.  2018
# 96                         FENMAN LTD  2014
# 97  Elsevier Science B.V., Amsterdam.  2019
# 98                        The Society  2015
# 99                           Springer  2016
#
# [100 rows x 6 columns]

# %%
# 모든 파일 합치기
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)
all_files_data_concat #출력하여 내용 확인
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1                  Big data promises big opportunity
# 1           NaN    2  Big data vs accurate data in health research: ...
# 2           NaN    3  Data stream classification and big data analytics
# 3           NaN    4  Big Data and Privacy: Why Public Organizations...
# 4           NaN    5  Big data on individuals in the architectural d...
# ..          ...  ...                                                ...
# 995         NaN   96  Efficient data management tools for the hetero...
# 996         NaN   97  Securing Big Data Provenance for Auditors: The...
# 997         NaN   98  Demystifying big data: Anatomy of big data dev...
# 998         NaN   99  Assessing Whether “Big Data” Solutions Provide...
# 999         NaN  100  Why Big Data Is a Big Deal A new class of data...
#
#                                                     저자  \
# 0                                            Davis, B.
# 1    Brodie, M.A.; Pliner, E.M.; Ho, A.; Li, Kalina...
# 2           Krawczyk, B.; Stefanowski, J.; Wozniak, M.
# 3                                  Prince, Christopher
# 4                Meekings, Scott; Schnabel, Marc Aurel
# ..                                                 ...
# 995  Alekseev, A. A.; Osipova, V. V.; Ivanov, M. A....
# 996                                  Appelbaum,  Deniz
# 997                                     Shin, Dong-Hee
# 998              Hertz, D.; Gavaghan, M.; Garfield, S.
# 999                                            unknown
#
#                                                    출판사   출판일
# 0                               INSTITUTE OF PETROLEUM  2014
# 1                     Elsevier Science B.V., Amsterdam  2018
# 2                    Elsevier Science B.V., Amsterdam.  2015
# 3                    University of Toronto Press; 1998  2017
# 4                                     Taylor & Francis  2017
# ..                                                 ...   ...
# 995                  Springer Science + Business Media  2016
# 996  Strategic and Emerging Technologies Section of...  2016
# 997                  Elsevier Science B.V., Amsterdam.  2016
# 998                   Elsevier Science B.V., Amsterdam  2014
# 999                             CW COMMUNICATIONS INC.  2011
#
# [1000 rows x 6 columns]

# %%
# 저장
#all_files_data_concat.to_csv('8장_data/riss_bigdata.csv', encoding='utf-8', index = False)

# %%
# 1-2. 데이터 전처리 (Pre-processing)

# 제목 추출
all_title = all_files_data_concat['제목']
all_title
# Out:
# 0                      Big data promises big opportunity
# 1      Big data vs accurate data in health research: ...
# 2      Data stream classification and big data analytics
# 3      Big Data and Privacy: Why Public Organizations...
# 4      Big data on individuals in the architectural d...
#                              ...
# 995    Efficient data management tools for the hetero...
# 996    Securing Big Data Provenance for Auditors: The...
# 997    Demystifying big data: Anatomy of big data dev...
# 998    Assessing Whether “Big Data” Solutions Provide...
# 999    Why Big Data Is a Big Deal A new class of data...
# Name: 제목, Length: 1000, dtype: object

# %%
# stop word 뽑아내기

import nltk
#nltk.download('punkt')    # 해보고 안되면 다음 명령어 실행
nltk.download('all')      # 5분 이상 소요됨

stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /Users/min0/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /Users/min0/nltk_data...
# [nltk_data]    | Downloading package kimmo to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /Users/min0/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /Users/min0/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /Users/min0/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package rslp to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /Users/min0/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
# 관사? 다 제거하고... 단어만 담기
words = []  

for title in all_title:
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title))    
    EnWordsToken = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop]
    words.append(EnWordsTokenStopLemma)

print(words)
# Out:
# [['big', 'data', 'promise', 'big', 'opportunity'], ['big', 'data', 'v', 'accurate', 'data', 'health', 'research', 'large', 'scale', 'physical', 'activity', 'monitoring', 'smartphones', 'wearable', 'device', 'risk', 'unconscious', 'bias'], ['data', 'stream', 'classification', 'big', 'data', 'analytics'], ['big', 'data', 'privacy', 'public', 'organization', 'adopt', 'big', 'data'], ['big', 'data', 'individual', 'architectural', 'design', 'process', 'combining', 'individual', 'data', 'architect', 'toolset'], ['big', 'data', 'operation', 'basis', 'benchmarking', 'data', 'grid'], ['big', 'data', 'benchmark', 'big', 'd'], ['big', 'data', 'ownership', 'data', 'recent', 'development', 'europe'], ['big', 'survey', 'big', 'data', 'centre'], ['big', 'data', 'approach', 'trauma', 'outcome', 'prediction', 'autonomous', 'resuscitation', 'shiming', 'yang', 'mary', 'njoku', 'colin', 'f', 'mackenzie', 'discus', 'massive', 'clinical', 'data', 'used', 'learning', 'prediction', 'model', 'level', 'trauma', 'centre', 'support', 'decision', 'making', 'trauma', 'patient'], ['big', 'data', 'becomes', 'big', 'business', 'computing', 'infrastructure'], ['big', 'data', 'analysis', 'signal', 'processing', 'graph', 'representation', 'processing', 'massive', 'data', 'set', 'irregular', 'structure'], ['big', 'data', 'data', 'science', 'health', 'care', 'nurse', 'midwife', 'need', 'know'], ['big', 'data', 'big', 'city', 'graph', 'signal', 'urban', 'air', 'pollution', 'exploratory', 'sp'], ['big', 'complex', 'biomedical', 'data', 'towards', 'taxonomy', 'data'], ['big', 'data', 'big', 'knowledge', 'brazilian', 'genomics', 'process', 'academic', 'marketization'], ['data', 'verification', 'task', 'scheduling', 'based', 'dynamic', 'resource', 'allocation', 'mobile', 'big', 'data', 'storage'], ['big', 'data', 'security', 'understanding', 'risk'], ['big', 'data', 'healthcare', 'life', 'science', 'learning', 'useful', 'insight', 'imperfect', 'data'], ['big', 'data', 'analytics', 'course', 'given', 'student', 'expectation', 'industry', 'demand', 'time', 'frame', 'content', 'make', 'analytics', 'course', 'big', 'data', 'friendly'], ['big', 'data', 'bigger', 'question', 'data', 'based', 'business', 'model', 'implication', 'organizational', 'boundary', 'data', 'governance', 'society'], ['data', 'ex', 'machina', 'introduction', 'big', 'data'], ['big', 'data', 'semiconductor', 'industry', 'front', 'lagging', 'behind', 'capital', 'equipment', 'supplier', 'must', 'provide', 'advanced', 'analytical', 'system', 'leverage', 'data', 'generated', 'tool', 'help', 'fab', 'customer', 'address', 'challenge', 'big', 'data', 'advanced', 'analytics'], ['data', 'intensive', 'application', 'challenge', 'technique', 'technology', 'survey', 'big', 'data'], ['big', 'data', 'management', 'security', 'application', 'telemetry', 'data', 'product'], ['data', 'modeling', 'age', 'big', 'data'], ['big', 'data', 'big', 'innovation', 'book', 'excerpt', 'enabling', 'competitive', 'differentiation', 'business', 'analytics'], ['big', 'data', 'big', 'data', 'set'], ['big', 'data', 'big', 'data'], ['big', 'data', 'medicine', 'big', 'deal'], ['big', 'data', 'big', 'concern', 'ethic', 'digital', 'age'], ['big', 'biotech', 'data', 'implementing', 'large', 'scale', 'data', 'processing', 'analysis', 'bioprocessing'], ['big', 'data', 'strategy', 'approach', 'business', 'driven', 'discovery', 'based'], ['big', 'data', 'big', 'opportunity', 'petroleum', 'petrochemical', 'industry'], ['big', 'data', 'cloud', 'bring', 'device', 'data', 'protection', 'law', 'address', 'impact', 'datafication'], ['data', 'transfer', 'scheduling', 'maximizing', 'throughput', 'big', 'data', 'computing', 'cloud', 'system'], ['big', 'data', 'second', 'three', 'article', 'l', 'amp', 'big', 'data', 'jonathan', 'kettleborough', 'examines', 'l', 'amp', 'historically', 'struggled', 'get', 'best', 'information'], ['big', 'data', 'open', 'data', 'closed', 'topic'], ['big', 'data', 'big', 'brother', 'china', 'us', 'social', 'medium', 'rate', 'ci ...

# %%
# 단어 리스트로 되어있는 거 합체
words2 = list(reduce(lambda x, y: x+y,words))
print(words2)
# Out:
# ['big', 'data', 'promise', 'big', 'opportunity', 'big', 'data', 'v', 'accurate', 'data', 'health', 'research', 'large', 'scale', 'physical', 'activity', 'monitoring', 'smartphones', 'wearable', 'device', 'risk', 'unconscious', 'bias', 'data', 'stream', 'classification', 'big', 'data', 'analytics', 'big', 'data', 'privacy', 'public', 'organization', 'adopt', 'big', 'data', 'big', 'data', 'individual', 'architectural', 'design', 'process', 'combining', 'individual', 'data', 'architect', 'toolset', 'big', 'data', 'operation', 'basis', 'benchmarking', 'data', 'grid', 'big', 'data', 'benchmark', 'big', 'd', 'big', 'data', 'ownership', 'data', 'recent', 'development', 'europe', 'big', 'survey', 'big', 'data', 'centre', 'big', 'data', 'approach', 'trauma', 'outcome', 'prediction', 'autonomous', 'resuscitation', 'shiming', 'yang', 'mary', 'njoku', 'colin', 'f', 'mackenzie', 'discus', 'massive', 'clinical', 'data', 'used', 'learning', 'prediction', 'model', 'level', 'trauma', 'centre', 'support', 'decision', 'making', 'trauma', 'patient', 'big', 'data', 'becomes', 'big', 'business', 'computing', 'infrastructure', 'big', 'data', 'analysis', 'signal', 'processing', 'graph', 'representation', 'processing', 'massive', 'data', 'set', 'irregular', 'structure', 'big', 'data', 'data', 'science', 'health', 'care', 'nurse', 'midwife', 'need', 'know', 'big', 'data', 'big', 'city', 'graph', 'signal', 'urban', 'air', 'pollution', 'exploratory', 'sp', 'big', 'complex', 'biomedical', 'data', 'towards', 'taxonomy', 'data', 'big', 'data', 'big', 'knowledge', 'brazilian', 'genomics', 'process', 'academic', 'marketization', 'data', 'verification', 'task', 'scheduling', 'based', 'dynamic', 'resource', 'allocation', 'mobile', 'big', 'data', 'storage', 'big', 'data', 'security', 'understanding', 'risk', 'big', 'data', 'healthcare', 'life', 'science', 'learning', 'useful', 'insight', 'imperfect', 'data', 'big', 'data', 'analytics', 'course', 'given', 'student', 'expectation', 'industry', 'demand', 'time', 'frame', 'content', 'make', 'analytics', 'course', 'big', 'data', 'friendly', 'big', 'data', 'bigger', 'question', 'data', 'based', 'business', 'model', 'implication', 'organizational', 'boundary', 'data', 'governance', 'society', 'data', 'ex', 'machina', 'introduction', 'big', 'data', 'big', 'data', 'semiconductor', 'industry', 'front', 'lagging', 'behind', 'capital', 'equipment', 'supplier', 'must', 'provide', 'advanced', 'analytical', 'system', 'leverage', 'data', 'generated', 'tool', 'help', 'fab', 'customer', 'address', 'challenge', 'big', 'data', 'advanced', 'analytics', 'data', 'intensive', 'application', 'challenge', 'technique', 'technology', 'survey', 'big', 'data', 'big', 'data', 'management', 'security', 'application', 'telemetry', 'data', 'product', 'data', 'modeling', 'age', 'big', 'data', 'big', 'data', 'big', 'innovation', 'book', 'excerpt', 'enabling', 'competitive', 'differentiation', 'business', 'analytics', 'big', 'data', 'big', 'data', 'set', 'big', 'data', 'big', 'data', 'big', 'data', 'medicine', 'big', 'deal', 'big', 'data', 'big', 'concern', 'ethic', 'digital', 'age', 'big', 'biotech', 'data', 'implementing', 'large', 'scale', 'data', 'processing', 'analysis', 'bioprocessing', 'big', 'data', 'strategy', 'approach', 'business', 'driven', 'discovery', 'based', 'big', 'data', 'big', 'opportunity', 'petroleum', 'petrochemical', 'industry', 'big', 'data', 'cloud', 'bring', 'device', 'data', 'protection', 'law', 'address', 'impact', 'datafication', 'data', 'transfer', 'scheduling', 'maximizing', 'throughput', 'big', 'data', 'computing', 'cloud', 'system', 'big', 'data', 'second', 'three', 'article', 'l', 'amp', 'big', 'data', 'jonathan', 'kettleborough', 'examines', 'l', 'amp', 'historically', 'struggled', 'get', 'best', 'information', 'big', 'data', 'open', 'data', 'closed', 'topic', 'big', 'data', 'big', 'brother', 'china', 'us', 'social', 'medium', 'rate', 'citizen', 'big', 'tiger', 'big', 'data', 'learning', 'social', 'reaction', 'chi ...

# %%
# 2. 데이터 탐색
# 2-1. 단어 빈도 탐색

count = Counter(words2)
count
# Out:
# Counter({'big': 1354,
#          'data': 1645,
#          'promise': 13,
#          'opportunity': 31,
#          'v': 3,
#          'accurate': 3,
#          'health': 37,
#          'research': 38,
#          'large': 18,
#          'scale': 12,
#          'physical': 3,
#          'activity': 2,
#          'monitoring': 7,
#          'smartphones': 1,
#          'wearable': 2,
#          'device': 10,
#          'risk': 12,
#          'unconscious': 1,
#          'bias': 3,
#          'stream': 8,
#          'classification': 8,
#          'analytics': 137,
#          'privacy': 17,
#          'public': 11,
#          'organization': 3,
#          'adopt': 1,
#          'individual': 6,
#          'architectural': 1,
#          'design': 14,
#          'process': 19,
#          'combining': 3,
#          'architect': 1,
#          'toolset': 1,
#          'operation': 6,
#          'basis': 1,
#          'benchmarking': 2,
#          'grid': 3,
#          'benchmark': 2,
#          'd': 1,
#          'ownership': 1,
#          'recent': 4,
#          'development': 8,
#          'europe': 2,
#          'survey': 19,
#          'centre': 6,
#          'approach': 44,
#          'trauma': 3,
#          'outcome': 5,
#          'prediction': 13,
#          'autonomous': 1,
#          'resuscitation': 1,
#          'shiming': 1,
#          'yang': 1,
#          'mary': 2,
#          'njoku': 1,
#          'colin': 1,
#          'f': 3,
#          'mackenzie': 1,
#          'discus': 5,
#          'massive': 4,
#          'clinical': 10,
#          'used': 3,
#          'learning': 33,
#          'model': 37,
#          'level': 3,
#          'support': 9,
#          'decision': 18,
#          'making': 19,
#          'patient': 11,
#          'becomes': 1,
#          'business': 18,
#          'computing': 25,
#          'infrastructure': 12,
#          'analysis': 67,
#          'signal': 3,
#          'processing': 30,
#          'graph': 10,
#          'representation': 6,
#          'set': 10,
#          'irregular': 1,
#          'structure': 5,
#          'science': 50,
#          'care': 17,
#          'nurse': 2,
#          'midwife': 1,
#          'need': 15,
#          'know': 6,
#          'city': 17,
#          'urban': 13,
#          'air': 3,
#          'pollution': 2,
#          'exploratory': 1,
#          'sp': 1,
#          'complex': 4,
#          'biomedical': 3,
#          'towards': 12,
#          'taxonomy': 2,
#          'knowledge': 22,
#          'brazilian': 3,
#          'genomics': 4,
#          'academic': 3,
#          'marketization': 1,
#          'verification': 2,
#          'task': 4,
#          'scheduling': 4,
#          'based': 62,
#          'dynamic': 7,
#          'resource': 5,
#          'allocation': 3,
#          'mobile': 8,
#          'storage': 21,
#          'security': 12,
#          'understanding': 11,
#          'healthcare': 21,
#          'life': 6,
#          'useful': 4,
#          'insight': 15,
#          'imperfect': 2,
#          'course': 4,
#          'given': 1,
#          'student': 5,
#          'expectation': 1,
#          'industry': 11,
#          'demand': 6,
#          'time': 17,
#          'frame': 1,
#          'content': 3,
#          'make': 10,
#          'friendly': 1,
#          'bigger': 7,
#          'question': 16,
#          'implication': 6,
#          'organizational': 2,
#          'boundary': 1,
#          'governance': 4,
#          'society': 4,
#          'ex': 1,
#          'machina': 1,
#          'introduction': 10,
#          'semiconductor': 1,
#          'front': 1,
#          'lagging': 1,
#          'behind': 3,
#          'capital': 2,
#          'equipment': 2,
#          'supplier': 1,
#          'must': 4,
#          'provide': 2,
#          'advanced': 5,
#          'analytical': 3,
#          'system': 50,
#          'leverage': 4,
#          'generated': 4,
#          'tool': 12,
#          'help': 8,
#          'fab': 1,
#          'customer': 5,
#          'address': 2,
#          'challenge': 47,
#          'intensive': 5,
#          'application': 25,
#          'technique': 7,
#          'technology': 28,
#          'management': 48,
#          'telemetry': 1,
#          'product': 6,
#          'modeling': 11,
#          'age': 3,
#          'innovation': 9,
#          'book': 3,
#          'excerpt': 1,
#          'enabling': 3,
#          'competitive': 6,
#          'differentiation': 1,
#          'medicine': 5,
#          'deal': 23,
#          'concern': 4,
#          'ethic': 4,
#          'digital': 10,
#          'biotech': 1,
#          'implementing': 3,
#          'bioprocessing': 1,
#          'strategy': 12,
#          'driven': 24,
#          'discovery': 13,
#          'petroleum': 1,
#          'petrochemical': 1,
#          'cloud': 34,
#          'bring': 2,
#          'protection': 13,
#          'law': 14,
#          'impact': 10,
#          'datafication': 1,
#          'transfer': 2,
#          'maximizing': 1,
#          'throughput': 3,
#          'second': 1,
#          'three': 3,
#          'article': 4,
#          'l': 5,
#          'amp': 7,
#          'jonathan': 3,
#          'kettleborough': 3,
#          'examines': 2,
#          'historically': 1,
#          'struggled': 1,
#          'get': 7,
#          'best': 9,
#          'information': 26,
#          'open': 20,
#          'closed': 1,
#          'topic': 1,
#          'brother': 7,
#          'china': 5,
#          'us': 2,
#          'social': 24,
#          'medium': 11,
#          'rate': 3,
#          'citizen': 2,
#          'tiger': 1,
#          'reaction': 2,
#          'anticorruption': 1,
#          'campaign': 2,
#          'online': 7,
#          'feedback': 1,
#          'blue': 2,
#          'fact': 2,
#          'corporation': 1,
#          'access': 3,
#          'ream': 1,
#          'stokes': 1,
#          'consumer': 7,
#          'fear': 1,
#          'company': 15,
#          'responding': 1,
#          'internal': 4,
#          'control': 9,
#          'policy': 5,
#          'ethical': 1,
#          'code': 2,
#          'greater': 1,
#          'candor': 1,
#          'collecting': 1,
#          'parsing': 1,
#          'personal': 5,
#          'marketing': 5,
#          'hype': 6,
#          'real': 14,
#          'finding': 6,
#          'valuable': 2,
#          'aging': 1,
#          'dementia': 1,
#          'pathway': 3,
#          'international': 7,
#          'harmonization': 1,
#          'sharing': 14,
#          'critical': 4,
#          'issue': 24,
#          'political': 6,
#          'sociology': 1,
#          'practice': 10,
#          'investigating': 1,
#          'language': 1,
#          'specific': 1,
#          'driver': 1,
#          'hotel': 2,
#          'satisfaction': 1,
#          'user': 5,
#          'review': 22,
#          'predictive': 14,
#          'manufacturing': 6,
#          'performance': 10,
#          'integrating': 2,
#          'institutional': 1,
#          'theory': 9,
#          'view': 4,
#          'culture': 1,
#          'automated': 3,
#          'actionable': 3,
#          'creation': 4,
#          'use': 22,
#          'human': 10,
#          'computer': 5,
#          'everywhere': 3,
#          'myth': 3,
#          'various': 2,
#          'stakeholder': 2,
#          'private': 2,
#          'sector': 8,
#          'concept': 3,
#          'positive': 1,
#          'negative': 1,
#          'trend': 6,
#          'stroke': 4,
#          'epidemiology': 3,
#          'united': 3,
#          'state': 10,
#          'good': 7,
#          'prefetching': 1,
#          'eviction': 1,
#          'mechanism': 1,
#          'memory': 5,
#          'result': 5,
#          'mining': 40,
#          'parameter': 2,
#          'layered': 2,
#          'framework': 26,
#          'pain': 4,
#          'gain': 7,
#          'lawyer': 3,
#          'progress': 2,
#          'headache': 3,
#          'next': 12,
#          'thing': 11,
#          'supply': 7,
#          'chain': 9,
#          'buzzword': 1,
#          'du': 1,
#          'jour': 1,
#          'c': 4,
#          'job': 3,
#          'michael': 3,
#          'stonebraker': 1,
#          'analyzes': 1,
#          'different': 3,
#          'variety': 2,
#          'judy': 1,
#          'robertson': 1,
#          'considers': 1,
#          'reward': 1,
#          'teaching': 2,
#          'effective': 7,
#          'visualization': 6,
#          'forecasting': 5,
#          'crime': 3,
#          'telecommunication': 1,
#          'operator': 3,
#          'platform': 19,
#          'sensing': 7,
#          'curation': 1,
#          'coming': 4,
#          'scalable': 13,
#          'center': 12,
#          'mitigation': 1,
#          'generation': 7,
#          'iot': 5,
#          'wireless': 4,
#          'sensor': 7,
#          'network': 23,
#          'audit': 3,
#          'liz': 1,
#          'sandwith': 1,
#          'chartered': 1,
#          'institute': 1,
#          'auditor': 2,
#          'look': 4,
#          'affect': 1,
#          'regulating': 2,
#          'phase': 3,
#          'current': 5,
#          'concerning': 2,
#          'pipe': 1,
#          'dream': 2,
#          'unleash': 2,
#          'huge': 3,
#          'turbine': 1,
#          'maintenance': 2,
#          'reliability': 2,
#          'savvy': 2,
#          'team': 5,
#          'skill': 3,
#          'action': 4,
#          'legal': 7,
#          'database': 11,
#          'allow': 2,
#          'reference': 3,
#          'librarian': 8,
#          'meet': 12,
#          'increasing': 1,
#          'comprehensive': 4,
#          'efficient': 22,
#          'solar': 2,
#          'power': 4,
#          'deep': 5,
#          'multiple': 5,
#          'source': 9,
#          'utility': 3,
#          'work': 7,
#          'revolution': 8,
#          'radiation': 4,
#          'biology': 6,
#          'overview': 4,
#          'historical': 1,
#          'contemporary': 1,
#          'landscape': 3,
#          'biomaterial': 1,
#          'archive': 3,
#          'problem': 13,
#          'precision': 3,
#          'neurocritical': 1,
#          'financial': 7,
#          'institution': 2,
#          'money': 8,
#          'fraud': 6,
#          'litigation': 2,
#          'fourth': 1,
#          'dogma': 1,
#          'ahead': 1,
#          'reprocessing': 2,
#          'among': 4,
#          'fda': 3,
#          'goal': 2,
#          'council': 2,
#          'want': 4,
#          'called': 2,
#          'evidence': 6,
#          'world': 16,
#          'experience': 5,
#          'improve': 9,
#          'reusable': 1,
#          'medical': 6,
#          'enhance': 2,
#          'cybersecurity': 2,
#          'fy': 1,
#          'regulatory': 3,
#          'magic': 1,
#          'talent': 1,
#          'using': 57,
#          'hard': 3,
#          'soft': 1,
#          'stuff': 1,
#          'easy': 2,
#          'phenotyping': 1,
#          'acute': 1,
#          'ischemic': 1,
#          'lesion': 1,
#          'segmentation': 1,
#          'multi': 11,
#          'magnetic': 1,
#          'resonance': 1,
#          'imaging': 5,
#          'stochastic': 2,
#          'robust': 2,
#          'optimization': 8,
#          'general': 4,
#          'computational': 5,
#          'algorithm': 17,
#          'leveraging': 7,
#          'machine': 15,
#          'uncertainty': 3,
#          'era': 22,
#          'biggest': 6,
#          'shake': 2,
#          'two': 3,
#          'decade': 1,
#          'regulation': 3,
#          'four': 4,
#          'month': 2,
#          'away': 1,
#          'already': 1,
#          'getting': 2,
#          'head': 1,
#          'round': 1,
#          'surrounding': 1,
#          'vesicoureteral': 1,
#          'reflux': 1,
#          'number': 4,
#          'minimal': 1,
#          'delay': 1,
#          'guaranteed': 1,
#          'resolution': 2,
#          'disaster': 4,
#          'area': 1,
#          'improved': 5,
#          'acquisition': 3,
#          'designing': 3,
#          'industrial': 4,
#          'future': 13,
#          'potential': 14,
#          'hammon': 1,
#          'explains': 3,
#          'planning': 7,
#          'unstructured': 3,
#          'warehousing': 4,
#          'olap': 1,
#          'art': 1,
#          'quality': 23,
#          'assurance': 3,
#          'traceability': 1,
#          'case': 13,
#          'study': 11,
#          'national': 4,
#          'standard': 1,
#          'program': 2,
#          'korea': 1,
#          'causation': 1,
#          'confounders': 1,
#          'cohort': 1,
#          'better': 3,
#          'offer': 6,
#          'numerous': 1,
#          'way': 12,
#          'add': 2,
#          'value': 15,
#          'danger': 1,
#          'sight': 1,
#          'eu': 5,
#          'regulator': 1,
#          'sentiment': 6,
#          'u': 12,
#          'collection': 8,
#          'government': 8,
#          'first': 5,
#          'provides': 6,
#          'bd': 2,
#          'role': 10,
#          'within': 2,
#          'lithium': 1,
#          'ion': 1,
#          'battery': 1,
#          'method': 18,
#          'sdae': 1,
#          'elm': 1,
#          'pre': 4,
#          'sclerosis': 1,
#          'web': 9,
#          'longitudinal': 3,
#          'viewer': 1,
#          'informatics': 3,
#          'efolder': 1,
#          'fusion': 3,
#          'small': 27,
#          'sample': 4,
#          'flying': 1,
#          'test': 3,
#          'simulation': 4,
#          'equivalent': 1,
#          'efficiency': 4,
#          'evaluation': 5,
#          'foundation': 3,
#          'rethinking': 5,
#          'behavior': 2,
#          'five': 4,
#          'guiding': 2,
#          'principle': 1,
#          'realizing': 2,
#          'imagining': 1,
#          'illustration': 1,
#          'news': 2,
#          'picture': 13,
#          'mouse': 2,
#          'badge': 2,
#          'cv': 2,
#          'backlash': 3,
#          'ax': 1,
#          'correlation': 2,
#          'measurement': 6,
#          'consequence': 6,
#          'come': 3,
#          'package': 3,
#          'connecting': 3,
#          'marketer': 6,
#          'extract': 3,
#          'maximum': 2,
#          'say': 5,
#          'iq': 1,
#          'stewart': 1,
#          'easterbrook': 1,
#          'insightful': 1,
#          'likely': 1,
#          'face': 3,
#          'paralysis': 1,
#          'confronting': 1,
#          'applying': 6,
#          'confrontation': 1,
#          'clause': 1,
#          'turning': 4,
#          'tiny': 1,
#          'constant': 1,
#          'size': 1,
#          'coresets': 1,
#          'k': 7,
#          'mean': 9,
#          'pca': 2,
#          'projective': 1,
#          'clustering': 7,
#          'sat': 1,
#          'combat': 3,
#          'thinking': 7,
#          'employing': 1,
#          'new': 38,
#          'convert': 1,
#          'volume': 6,
#          'available': 2,
#          'chemical': 2,
#          'incremental': 3,
#          'generative': 1,
#          'topographic': 1,
#          'mapping': 5,
#          'electric': 3,
#          'ceo': 1,
#          'disruptive': 1,
#          'climate': 3,
#          'change': 9,
#          'propulsion': 1,
#          'usage': 2,
#          'scholarly': 4,
#          'extraction': 4,
#          'progressive': 1,
#          'warehouse': 14,
#          'provenance': 3,
#          'supervision': 1,
#          'prov': 1,
#          'dm': 1,
#          'twitter': 4,
#          'brain': 4,
#          'interface': 2,
#          'enabled': 6,
#          'consolidated': 1,
#          'energy': 10,
#          'software': 8,
#          'defined': 3,
#          'setup': 1,
#          'exploring': 5,
#          'traditional': 2,
#          'enterprise': 5,
#          'save': 3,
#          'ntt': 1,
#          'uk': 2,
#          'without': 1,
#          'begin': 2,
#          'end': 6,
#          'versus': 5,
#          'alternative': 3,
#          'measure': 4,
#          'aggregate': 1,
#          'predict': 1,
#          'presidential': 1,
#          'election': 1,
#          'recommendation': 2,
#          'engine': 2,
#          'local': 2,
#          'pattern': 3,
#          'sourced': 1,
#          'visual': 6,
#          'sublime': 3,
#          'diagrammatic': 3,
#          'visualisation': 4,
#          'validate': 1,
#          'thermodynamic': 1,
#          'specie': 1,
#          'handling': 5,
#          'astronomy': 2,
#          'astrophysics': 1,
#          'rich': 3,
#          'structured': 2,
#          'query': 6,
#          'replicated': 1,
#          'xtreemfs': 1,
#          'price': 1,
#          'consideration': 3,
#          'building': 8,
#          'solve': 1,
#          'reporting': 1,
#          'obesity': 2,
#          'line': 2,
#          'foresight': 1,
#          'map': 4,
#          'transitioning': 1,
#          'working': 1,
#          'collected': 3,
#          'toward': 7,
#          'lab': 3,
#          'rat': 1,
#          'tracker': 1,
#          'ttrap': 1,
#          'dweller': 1,
#          'prescription': 3,
#          'australia': 3,
#          'experiment': 4,
#          'neuroimaging': 1,
#          'sifting': 1,
#          'smooth': 1,
#          'e': 7,
#          'p': 5,
#          'analyst': 1,
#          'feed': 1,
#          'forget': 1,
#          'beware': 1,
#          'little': 12,
#          'artificial': 3,
#          'intelligence': 9,
#          'unsupervised': 2,
#          'operational': 1,
#          'enhancement': 1,
#          'project': 8,
#          'internet': 10,
#          'methodology': 3,
#          'cyberterrorism': 1,
#          'vocabulary': 1,
#          'detection': 6,
#          'nlp': 1,
#          'semantic': 7,
#          'fix': 1,
#          'expert': 6,
#          'possible': 1,
#          'pitfall': 6,
#          'creating': 7,
#          'flow': 7,
#          'smart': 34,
#          'cross': 1,
#          'novel': 4,
#          'mainframe': 1,
#          'elephant': 1,
#          'room': 1,
#          'protocol': 1,
#          'minimize': 1,
#          'pharmacovigilance': 1,
#          'emerging': 7,
#          'accidental': 2,
#          'scientist': 9,
#          'professional': 5,
#          'close': 1,
#          'gap': 4,
#          'minister': 1,
#          'acknowledge': 1,
#          'ensure': 2,
#          'everything': 1,
#          'done': 3,
#          'protect': 2,
#          'nh': 1,
#          'pcn': 1,
#          'cancer': 2,
#          'treatment': 7,
#          'germany': 1,
#          'german': 3,
#          'statutory': 1,
#          'insurance': 1,
#          'shi': 1,
#          'claim': 2,
#          'scientific': 6,
#          'stay': 3,
#          'relevant': 2,
#          'space': 6,
#          'many': 3,
#          'satellite': 4,
#          'orbit': 1,
#          'bounce': 1,
#          'catapult': 1,
#          'exploit': 2,
#          'market': 18,
#          'guest': 12,
#          'editorial': 17,
#          'behavioral': 4,
#          'cover': 2,
#          'story': 1,
#          'everybody': 3,
#          'lie': 3,
#          'tell': 6,
#          'really': 7,
#          'sethstephens': 1,
#          'davidowitz': 2,
#          'york': 2,
#          'harpercollins': 1,
#          'pp': 5,
#          'equal': 1,
#          'prostate': 1,
#          'electronic': 3,
#          'capture': 5,
#          'changing': 1,
#          'scope': 2,
#          'trial': 4,
#          'putting': 2,
#          'spark': 3,
#          'streaming': 1,
#          'acting': 1,
#          'info': 1,
#          'pro': 1,
#          'interpret': 1,
#          'report': 7,
#          'contribution': 2,
#          'informal': 1,
#          'neighborhood': 1,
#          'adoption': 1,
#          'defining': 2,
#          'examining': 1,
#          'factor': 3,
#          'affecting': 1,
#          'direction': 2,
#          'managing': 4,
#          'smarter': 1,
#          'firm': 3,
#          'gold': 3,
#          'transforming': 4,
#          'linked': 6,
#          'ontology': 4,
#          'environment': 18,
#          'dbgoldbr': 1,
#          'illustrate': 1,
#          'shared': 2,
#          'multipurpose': 1,
#          'paper': 8,
#          'sparse': 4,
#          'adic': 1,
#          'coding': 3,
#          'computationally': 1,
#          'laboratory': 2,
#          'across': 3,
#          'manufacturer': 2,
#          'prerequisite': 1,
#          'schema': 1,
#          'engineering': 5,
#          'gene': 1,
#          'expression': 1,
#          'programming': 2,
#          'metadata': 6,
#          'preliminary': 4,
#          'investigation': 3,
#          'repository': 5,
#          'bespoke': 1,
#          'solution': 13,
#          'tackle': 2,
#          'try': 1,
#          'simplify': 2,
#          'regular': 1,
#          'radiology': 1,
#          'easiest': 1,
#          'answer': 4,
#          'longer': 1,
#          'fit': 2,
#          'excel': 1,
#          'mptcp': 1,
#          'customizing': 1,
#          'transmission': 2,
#          'capacity': 3,
#          'inevitable': 1,
#          'drowning': 1,
#          'generating': 2,
#          'vast': 3,
#          'quantity': 3,
#          'fuss': 1,
#          'beat': 2,
#          'special': 12,
#          'engineer': 2,
#          'enough': 2,
#          'gps': 1,
#          'travel': 1,
#          'die': 1,
#          'vorstandsperspektive': 1,
#          'wealth': 1,
#          'augmenting': 2,
#          'curriculum': 1,
#          'editor': 2,
#          'versatile': 1,
#          'retrieval': 3,
#          'geospatial': 3,
#          'busting': 1,
#          'led': 1,
#          'whether': 3,
#          'overrated': 1,
#          'bright': 1,
#          'north': 2,
#          'rob': 2,
#          'hick': 1,
#          'belief': 1,
#          'pointer': 1,
#          'dazzled': 1,
#          'census': 1,
#          'geography': 1,
#          'perspective': 21,
#          'outlier': 1,
#          'missing': 2,
#          'fair': 2,
#          'trade': 1,
#          'virtual': 3,
#          'bank': 4,
#          'free': 1,
#          'rider': 1,
#          'promotion': 1,
#          'facilitation': 1,
#          'biopharmaceutical': 1,
#          'omics': 2,
#          'seeing': 1,
#          'lensless': 1,
#          'camera': 3,
#          'advance': 5,
#          'optic': 2,
#          'think': 2,
#          'photography': 1,
#          'day': 3,
#          'secure': 2,
#          'low': 2,
#          'cost': 5,
#          'remote': 7,
#          'integrity': 3,
#          'checking': 1,
#          'last': 1,
#          'indexing': 4,
#          'encrypted': 2,
#          'connection': 1,
#          'remain': 2,
#          'retail': 2,
#          'clinic': 2,
#          'shadow': 1,
#          'hurricane': 1,
#          'sandy': 2,
#          'uncovering': 1,
#          'sociospatial': 1,
#          'dimension': 4,
#          'master': 2,
#          'unlock': 2,
#          'sustainable': 4,
#          'resilient': 1,
#          'loss': 2,
#          'actually': 3,
#          'theft': 2,
#          'preparing': 2,
#          'pedagogic': 1,
#          'minitrack': 1,
#          'macrosystems': 1,
#          'ecology': 2,
#          'publicly': 1,
#          'pediatric': 1,
#          'mental': 1,
#          'child': 2,
#          'carpool': 1,
#          'crowd': 1,
#          'cooperation': 1,
#          'pervasive': 1,
#          'ai': 2,
#          'engaging': 1,
#          'occupational': 1,
#          'therapy': 3,
#          'recognise': 1,
#          'symposium': 1,
#          'utilizing': 2,
#          'milk': 1,
#          'fourier': 1,
#          'transform': 2,
#          'infrared': 1,
#          'hyperketonemia': 1,
#          'ackoff': 1,
#          'interactive': 1,
#          'respond': 2,
#          'emergent': 2,
#          'hybrid': 4,
#          'bang': 4,
#          'crunch': 3,
#          'solving': 1,
#          'crystal': 1,
#          'powder': 1,
#          'diffraction': 1,
#          'spatial': 10,
#          'economic': 3,
#          'smallclient': 1,
#          'fast': 5,
#          'interoperability': 2,
#          'maturity': 2,
#          'capability': 3,
#          'portfolio': 1,
#          'still': 1,
#          'pocket': 1,
#          'baidu': 1,
#          'reptile': 1,
#          'frequency': 1,
#          'partitioning': 4,
#          'distributed': 18,
#          'electricity': 1,
#          'reform': 2,
#          'remaining': 1,
#          'forward': 1,
#          'auditing': 1,
#          'securing': 2,
#          'incorrect': 1,
#          'cleaning': 2,
#          'machinery': 1,
#          'condition': 4,
#          'connected': 4,
#          'car': 1,
#          'service': 21,
#          'optimizing': 2,
#          'read': 3,
#          'hadoop': 7,
#          'act': 1,
#          'nosql': 4,
#          'hbase': 1,
#          'adept': 1,
#          'reining': 1,
#          'may': 2,
#          'harness': 2,
#          'buzz': 2,
#          'amy': 1,
#          'affelt': 1,
#          'overcoming': 1,
#          'drought': 1,
#          'scoring': 1,
#          'rush': 1,
#          'provider': 2,
#          'benefit': 8,
#          'hdac': 1,
#          ...})

# %%
# 가장 빈번한 단어 50개 찾기
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1): # tag가 1이상인 것들만
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1645
# big : 1354
# analytics : 137
# analysis : 67
# based : 62
# using : 57
# science : 50
# system : 50
# management : 48
# challenge : 47
# approach : 44
# mining : 40
# research : 38
# new : 38
# health : 37
# model : 37
# cloud : 34
# smart : 34
# learning : 33
# opportunity : 31
# processing : 30
# technology : 28
# small : 27
# information : 26
# framework : 26
# computing : 25
# application : 25
# driven : 24
# social : 24
# issue : 24
# deal : 23
# network : 23
# quality : 23
# knowledge : 22
# review : 22
# use : 22
# efficient : 22
# era : 22
# storage : 21
# healthcare : 21
# perspective : 21
# service : 21
# open : 20
# process : 19
# survey : 19
# making : 19
# platform : 19
# large : 18
# decision : 18
# business : 18

# %%
# #### 여기서 잠깐!! : 검색어로 사용한 big'과 'data' 빈도가 압도적으로 많으므로, 이를 제거한다.

#검색어로 사용한 'big'과 'data' 항목 제거 하기
del word_count['big']
del word_count['data']

# %%
# 2-2 빅데이터 단어 빈도 히스토그램

# 히스토그램 표시 옵션 
plt.figure(figsize=(12,5))
plt.xlabel("word")
plt.ylabel("count")
plt.grid(True)

# 정렬
sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(), reverse=True)

# 바 차트 그리기
plt.bar(range(len(word_count)), sorted_Values, align='center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation='85')

plt.show()

# %%
# 3. 분석 모델 구축 및 결과 시각화
# 3-1. 연도별 데이터 수

all_files_data_concat['doc_count'] = 0
summary_year = all_files_data_concat.groupby('출판일', as_index=False)['doc_count'].count()
summary_year
# Out:
#      출판일  doc_count
# 0   1994          1
# 1   1995          1
# 2   1996          1
# 3   1998          3
# 4   2002          4
# 5   2003          1
# 6   2004          3
# 7   2005          3
# 8   2007          2
# 9   2008          3
# 10  2009          2
# 11  2010          3
# 12  2011          8
# 13  2012         34
# 14  2013         87
# 15  2014        154
# 16  2015        114
# 17  2016        139
# 18  2017        158
# 19  2018        130
# 20  2019        106
# 21  2020         43

# %%
# 위에꺼 시각화
plt.figure(figsize=(12,5))
plt.xlabel("year")
plt.ylabel("doc-count")
plt.grid(True)

plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt.xticks(range(len(summary_year)), [text for text in summary_year['출판일']])

plt.show()

# %%
# 3-2. 워드클라우드

stopwords=set(STOPWORDS)
wc=WordCloud(background_color='ivory', stopwords=stopwords, width=800, height=600)
cloud=wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
# #### - 워드 클라우드에 나타나는 단어의 위치는 실행 할 때마다 달라진다. ☺

cloud.to_file("8장_data/riss_bigdata_wordCloud.jpg")
